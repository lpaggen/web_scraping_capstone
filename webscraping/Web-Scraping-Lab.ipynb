# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Hands-on Lab : Web Scraping**

# %% [markdown]
# Estimated time needed: **30 to 45** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# * Extract information from a given web site
# * Write the scraped data into a csv file.

# %% [markdown]
# ## Extract information from the given web site
# You will extract the data from the below web site: <br>

# %%
#this url contains the data you need to scrape
link = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# The data you need to scrape is the **name of the programming language** and **average annual salary**.<br> It is a good idea to open the url in your web broswer and study the contents of the web page before you start to scrape.

# %% [markdown]
# Import the required libraries

# %%
# Your code here
import requests
from bs4 import BeautifulSoup
import html5lib

# %% [markdown]
# Download the webpage at the url

# %%
#your code goes here
url = link
data = requests.get(url).text

# %% [markdown]
# Create a soup object

# %%
#your code goes here
soup = BeautifulSoup(url, 'html5lib')
# Out:
# /var/folders/28/nqw3v6ld39g_jrhl3y66nq2w0000gn/T/ipykernel_99930/3775845800.py:2: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   soup = BeautifulSoup(url, 'html5lib')

# %% [markdown]
# Scrape the `Language name` and `annual average salary`.

# %%
#your code goes here
table = soup.find('table')
# Out:
# NoneType

# %% [markdown]
# Save the scrapped data into a file named *popular-languages.csv*

# %%
import pandas as pd
results = []

for row in table.find_all('tr'):
    cols = row.find_all('td')
    language = cols[1].getText()
    salary = cols[3].getText()
    results.append([language,salary])

df = pd.DataFrame(results)
df.to_csv()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/lpaggen/Downloads/Web-Scraping-Lab.ipynb Cell 19 line 4
#       <a href='vscode-notebook-cell:/Users/lpaggen/Downloads/Web-Scraping-Lab.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/Users/lpaggen/Downloads/Web-Scraping-Lab.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> results = []
# ----> <a href='vscode-notebook-cell:/Users/lpaggen/Downloads/Web-Scraping-Lab.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> for row in table.find_all('tr'):
#       <a href='vscode-notebook-cell:/Users/lpaggen/Downloads/Web-Scraping-Lab.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a>     cols = row.find_all('td')
#       <a href='vscode-notebook-cell:/Users/lpaggen/Downloads/Web-Scraping-Lab.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a>     language = cols[1].getText()
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-10-17  | 0.1  | Ramesh Sannareddy  |  Created initial version of the lab |

# %% [markdown]
#  Copyright &copy; 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01).
